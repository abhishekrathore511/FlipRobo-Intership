# %%
import pandas as pd 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('brain_size.csv' , sep=';')

# %%
df
# Out:
#     id  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 0    1  Female   133  132  124    118   64.5     816932
# 1    2    Male   140  150  124      .   72.5    1001121
# 2    3    Male   139  123  150    143   73.3    1038437
# 3    4    Male   133  129  128    172   68.8     965353
# 4    5  Female   137  132  134    147   65.0     951545
# 5    6  Female    99   90  110    146   69.0     928799
# 6    7  Female   138  136  131    138   64.5     991305
# 7    8  Female    92   90   98    175   66.0     854258
# 8    9    Male    89   93   84    134   66.3     904858
# 9   10    Male   133  114  147    172   68.8     955466
# 10  11  Female   132  129  124    118   64.5     833868
# 11  12    Male   141  150  128    151   70.0    1079549
# 12  13    Male   135  129  124    155   69.0     924059
# 13  14  Female   140  120  147    155   70.5     856472
# 14  15  Female    96  100   90    146   66.0     878897
# 15  16  Female    83   71   96    135   68.0     865363
# ...

# %%
df.head()
# Out:
#    id  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 0   1  Female   133  132  124    118   64.5     816932
# 1   2    Male   140  150  124      .   72.5    1001121
# 2   3    Male   139  123  150    143   73.3    1038437
# 3   4    Male   133  129  128    172   68.8     965353
# 4   5  Female   137  132  134    147   65.0     951545

# %%
df.head(10)
# Out:
#    id  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 0   1  Female   133  132  124    118   64.5     816932
# 1   2    Male   140  150  124      .   72.5    1001121
# 2   3    Male   139  123  150    143   73.3    1038437
# 3   4    Male   133  129  128    172   68.8     965353
# 4   5  Female   137  132  134    147   65.0     951545
# 5   6  Female    99   90  110    146   69.0     928799
# 6   7  Female   138  136  131    138   64.5     991305
# 7   8  Female    92   90   98    175   66.0     854258
# 8   9    Male    89   93   84    134   66.3     904858
# 9  10    Male   133  114  147    172   68.8     955466

# %%
df.tail()
# Out:
#     id  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 35  36  Female   133  129  128    153   66.5     948066
# 36  37    Male   140  150  124    144   70.5     949395
# 37  38  Female    88   86   94    139   64.5     893983
# 38  39    Male    81   90   74    148   74.0     930016
# 39  40    Male    89   91   89    179   75.5     935863

# %%
df.tail(10)
# Out:
#     id  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 30  31  Female   133  126  132    127   62.5     857782
# 31  32    Male   144  145  137    191   67.0     949589
# 32  33    Male   103   96  110    192   75.5     997925
# 33  34    Male    90   96   86    181   69.0     879987
# 34  35  Female    83   90   81    143   66.5     834344
# 35  36  Female   133  129  128    153   66.5     948066
# 36  37    Male   140  150  124    144   70.5     949395
# 37  38  Female    88   86   94    139   64.5     893983
# 38  39    Male    81   90   74    148   74.0     930016
# 39  40    Male    89   91   89    179   75.5     935863

# %%
df.sample()
# Out:
#     id Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 25  26   Male   141  145  131    171   72.0     935494

# %%
df.sample(5)
# Out:
#     id  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 4    5  Female   137  132  134    147   65.0     951545
# 27  28    Male   103   96  110    187   77.0    1062462
# 33  34    Male    90   96   86    181   69.0     879987
# 1    2    Male   140  150  124      .   72.5    1001121
# 31  32    Male   144  145  137    191   67.0     949589

# %%
df.shape
# Out:
# (40, 8)

# %%
df.dtypes
# Out:
# id            int64
# Gender       object
# FSIQ          int64
# VIQ           int64
# PIQ           int64
# Weight       object
# Height       object
# MRI_Count     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         40 non-null     int64
#  1   Gender     40 non-null     object
#  2   FSIQ       40 non-null     int64
#  3   VIQ        40 non-null     int64
#  4   PIQ        40 non-null     int64
#  5   Weight     40 non-null     object
#  6   Height     40 non-null     object
#  7   MRI_Count  40 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 2.6+ KB

# %%
df.isnull()
# Out:
#        id  Gender   FSIQ    VIQ    PIQ  Weight  Height  MRI_Count
# 0   False   False  False  False  False   False   False      False
# 1   False   False  False  False  False   False   False      False
# 2   False   False  False  False  False   False   False      False
# 3   False   False  False  False  False   False   False      False
# 4   False   False  False  False  False   False   False      False
# 5   False   False  False  False  False   False   False      False
# 6   False   False  False  False  False   False   False      False
# 7   False   False  False  False  False   False   False      False
# 8   False   False  False  False  False   False   False      False
# 9   False   False  False  False  False   False   False      False
# 10  False   False  False  False  False   False   False      False
# 11  False   False  False  False  False   False   False      False
# 12  False   False  False  False  False   False   False      False
# ...

# %%
df.isnull().sum()
# Out:
# id           0
# Gender       0
# FSIQ         0
# VIQ          0
# PIQ          0
# Weight       0
# Height       0
# MRI_Count    0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height', 'MRI_Count'], dtype='object')

# %%
df.describe()
# Out:
#               id        FSIQ         VIQ        PIQ     MRI_Count
# count  40.000000   40.000000   40.000000   40.00000  4.000000e+01
# mean   20.500000  113.450000  112.350000  111.02500  9.087550e+05
# std    11.690452   24.082071   23.616107   22.47105  7.228205e+04
# min     1.000000   77.000000   71.000000   72.00000  7.906190e+05
# 25%    10.750000   89.750000   90.000000   88.25000  8.559185e+05
# 50%    20.500000  116.500000  113.000000  115.00000  9.053990e+05
# 75%    30.250000  135.500000  129.750000  128.00000  9.500780e+05
# max    40.000000  144.000000  150.000000  150.00000  1.079549e+06

# %%
#df,NRI_count,unique

# %%
df["Gender"].value_counts()
# Out:
# Female    20
# Male      20
# Name: Gender, dtype: int64

# %%
df.head()
# Out:
#    id  Gender  FSIQ  VIQ  PIQ Weight Height  MRI_Count
# 0   1  Female   133  132  124    118   64.5     816932
# 1   2    Male   140  150  124      .   72.5    1001121
# 2   3    Male   139  123  150    143   73.3    1038437
# 3   4    Male   133  129  128    172   68.8     965353
# 4   5  Female   137  132  134    147   65.0     951545

# %%
sns.countplot(x='Gender',data=df)

# %%
df['Height'].value_counts()
# Out:
# 64.5    4
# 69.0    3
# 66.5    3
# 68.0    3
# 68.8    2
# 66.0    2
# 66.3    2
# 70.0    2
# 63.0    2
# 70.5    2
# 75.5    2
# 72.0    1
# 77.0    1
# 72.5    1
# .       1
# 76.5    1
# 62.0    1
# 73.5    1
# 74.0    1
# 68.5    1
# 73.3    1
# 67.0    1
# 65.0    1
# 62.5    1
# Name: Height, dtype: int64

# %%
sns.distplot(df['Weight'],kde=False,bins=20)

# %%
df.dtypes
# Out:
# id            int64
# Gender       object
# FSIQ          int64
# VIQ           int64
# PIQ           int64
# Weight       object
# Height       object
# MRI_Count     int64
# dtype: object

# %%
df['Height'].dtypes
# Out:
# dtype('O')

# %%
df['Height'].str.strip()
# Out:
# 0     64.5
# 1     72.5
# 2     73.3
# 3     68.8
# 4     65.0
# 5     69.0
# 6     64.5
# 7     66.0
# 8     66.3
# 9     68.8
# 10    64.5
# 11    70.0
# 12    69.0
# 13    70.5
# 14    66.0
# 15    68.0
# 16    68.5
# 17    73.5
# 18    66.3
# 19    70.0
# 20       .
# 21    76.5
# 22    62.0
# 23    68.0
# 24    63.0
# 25    72.0
# 26    68.0
# 27    77.0
# 28    63.0
# 29    66.5
# 30    62.5
# 31    67.0
# 32    75.5
# 33    69.0
# 34    66.5
# 35    66.5
# 36    70.5
# 37    64.5
# 38    74.0
# 39    75.5
# Name: Height, dtype: object

# %%
df['Height'].dtypes
# Out:
# dtype('O')

# %%
df['Height'][:4]
# Out:
# 0    64.5
# 1    72.5
# 2    73.3
# 3    68.8
# Name: Height, dtype: object

# %%
plt.hist(df['Height'],bins=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7a298ebcd718> in <module>
# ----> 1 plt.hist(df['Height'],bins=10)
#
# NameError: name 'plt' is not defined

# %%
df['Height'].dtypes
# Out:
# dtype('O')

# %%
df.iloc[1,-3]
# Out:
# '.'

# %%
drop_rows=df[df['Height'] =='.'].index

# %%
df.drop(drop_rows, inplace=True)

# %%
df['Height'].dtypes
# Out:
# dtype('O')

# %%
df.iloc[20,-2]
# Out:
# '76.5'

# %%
drop_rows=df[df['Weight'] =='.'].index

# %%
df.drop(drop_rows, inplace=True)

# %%
df.iloc[1,-3]
# Out:
# '143'

# %%
sns.distplot(df['Height'],bins=10)

# %%
sns.distplot(df['Weight'],kde=False,bins=20)

# %%
df['Weight'].plot.box()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-f6b3921579c4> in <module>
# ----> 1 df['Weight'].plot.box()
#
# ~\anaconda4\lib\site-packages\pandas\plotting\_core.py in box(self, by, **kwargs)
#    1131             >>> ax = df.plot.box()
#    1132         """
# -> 1133         return self(kind="box", by=by, **kwargs)
#    1134
#    1135     def hist(self, by=None, bins=10, **kwargs):
#
# ~\anaconda4\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda4\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
df['Height'].str.strip()
# Out:
# 0     64.5
# 2     73.3
# 3     68.8
# 4     65.0
# 5     69.0
# 6     64.5
# 7     66.0
# 8     66.3
# 9     68.8
# 10    64.5
# 11    70.0
# 12    69.0
# 13    70.5
# 14    66.0
# 15    68.0
# 16    68.5
# 17    73.5
# 18    66.3
# 19    70.0
# 21    76.5
# 22    62.0
# 23    68.0
# 24    63.0
# 25    72.0
# 26    68.0
# 27    77.0
# 28    63.0
# 29    66.5
# 30    62.5
# 31    67.0
# 32    75.5
# 33    69.0
# 34    66.5
# 35    66.5
# 36    70.5
# 37    64.5
# 38    74.0
# 39    75.5
# Name: Height, dtype: object
